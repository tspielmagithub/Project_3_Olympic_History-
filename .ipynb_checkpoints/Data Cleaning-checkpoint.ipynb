# %%
import pandas as pd

# %%
athlete_events = pd.read_csv('olympic_data/athlete_events.csv')
noc_regions = pd.read_csv('olympic_data/noc_regions.csv')

# %%
athlete_events
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
athlete_events.astype({'Age': 'string'}).dtypes
# Out:
# ID                 int64
# Name              object
# Sex               object
# Age       string[python]
# Height           float64
# Weight           float64
# Team              object
# NOC               object
# Games             object
# Year               int64
# Season            object
# City              object
# Sport             object
# Event             object
# Medal             object
# dtype: object

# %%
athlete_events.insert(0, 'Row', range(0, 0 + len(athlete_events)))

# %%
athlete_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 16 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Row     271116 non-null  int64
#  1   ID      271116 non-null  int64
#  2   Name    271116 non-null  object
#  3   Sex     271116 non-null  object
#  4   Age     261642 non-null  float64
#  5   Height  210945 non-null  float64
#  6   Weight  208241 non-null  float64
#  7   Team    271116 non-null  object
#  8   NOC     271116 non-null  object
#  9   Games   271116 non-null  object
#  10  Year    271116 non-null  int64
#  11  Season  271116 non-null  object
#  12  City    271116 non-null  object
#  13  Sport   271116 non-null  object
#  14  Event   271116 non-null  object
#  15  Medal   39783 non-null   object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 33.1+ MB

# %%
athlete_events.isna().any()
# Out:
# Row       False
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# dtype: bool

# %%
athlete_events_cleaned = athlete_events.fillna('')
# Out:
# /var/folders/kg/60_z3q496c1dyv52cdlddz7h0000gn/T/ipykernel_4491/3077344919.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   athlete_events.fillna('', inplace = True)
#    Row  ID                      Name Sex   Age Height Weight            Team  \
# 0    0   1                 A Dijiang   M  24.0  180.0   80.0           China
# 1    1   2                  A Lamusi   M  23.0  170.0   60.0           China
# 2    2   3       Gunnar Nielsen Aaby   M  24.0                       Denmark
# 3    3   4      Edgar Lindenau Aabye   M  34.0                Denmark/Sweden
# 4    4   5  Christine Jacoba Aaftink   F  21.0  185.0   82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# ...

# %%
athlete_events_cleaned.head()
# Out:
#    Row  ID                      Name Sex   Age Height Weight            Team  \
# 0    0   1                 A Dijiang   M  24.0  180.0   80.0           China
# 1    1   2                  A Lamusi   M  23.0  170.0   60.0           China
# 2    2   3       Gunnar Nielsen Aaby   M  24.0                       Denmark
# 3    3   4      Edgar Lindenau Aabye   M  34.0                Denmark/Sweden
# 4    4   5  Christine Jacoba Aaftink   F  21.0  185.0   82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball
# 1      Judo Men's Extra-Lightweight
# ...

# %%
athlete_events_cleaned.isna().any()
# Out:
# Row       False
# ID        False
# Name      False
# Sex       False
# Age       False
# Height    False
# Weight    False
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal     False
# dtype: bool

# %%
athlete_events_cleaned.to_csv('olympic_data/noc_regions.csv')

# %%
noc_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
noc_regions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NOC     230 non-null    object
#  1   region  227 non-null    object
#  2   notes   21 non-null     object
# dtypes: object(3)
# memory usage: 5.5+ KB

# %%
noc_regions.isna().any()
# Out:
# NOC       False
# region     True
# notes      True
# dtype: bool

# %%
noc_regions_cleaned = noc_regions.fillna('')

# %%
noc_regions_cleaned.isna().any()
# Out:
# NOC       False
# region    False
# notes     False
# dtype: bool

# %%
noc_regions_cleaned.to_csv('olympic_data/noc_regions_cleaned.csv')
